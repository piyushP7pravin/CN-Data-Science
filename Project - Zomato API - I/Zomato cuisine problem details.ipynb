# %%
# key : ##################################

# %%
import requests

# %% [markdown]
# # Zomato Cuisine 1.1

# %%
response = requests.get('https://developers.zomato.com/api/v2.1/cuisines',
                        headers = {'user-key':'##################################'},
                       params={"city_id":"1"})
py_data = response.json()
for i in py_data["cuisines"]:
    if i["cuisine"]["cuisine_name"]=="Mexican":
        print(i["cuisine"]["cuisine_id"])
# Out:
# 73

# %% [markdown]
# # Zomato Cuisine 1.3

# %%
response = requests.get('https://developers.zomato.com/api/v2.1/locations',
                        headers = {'user-key':'##################################'},
                       params={"query":"Connaught Place"})
py_data = response.json()
print(py_data["location_suggestions"][0]["entity_type"],py_data["location_suggestions"][0]["entity_id"])
# Out:
# subzone 104

# %% [markdown]
# # Zomato Cuisine 1.4

# %%
response = requests.get('https://developers.zomato.com/api/v2.1/search',
                        headers = {'user-key':'##################################'},
                       params={"entity_id":"104",
                               "entity_type":"subzone", 
                               "count":10,
                               "cuisines":"73",
                               "sort":"rating",
                               "order":"desc"}
                       ) 
py_data = response.json()
for i in py_data["restaurants"]:
    print(i["restaurant"]["name"],i["restaurant"]["user_rating"]["aggregate_rating"],i["restaurant"]["id"])
# Out:
# Odeon Social 4.7 18246991
# 38 Barracks 4.7 18241537
# Connaught Clubhouse 4.6 19295106
# Detroit 4.5 18625812
# Ministry Of Beer 4.5 18418277
# Chili's Grill & Bar 4.5 18537536
# Farzi Cafe 4.3 18233593
# Xero Degrees 4.3 18729557
# Lord Of The Drinks 4.3 312603
# The Junkyard Cafe 4.3 313256

# %%
import requests
response = requests.get('https://developers.zomato.com/api/v2.1/search',
                        headers = {'user-key':'fe2800d53acb7eea4371a2f92dad232b'},
                       params={"entity_id":"104",
                               "entity_type":"subzone", 
                               "count":10,
                               
                               "sort":"rating",
                               "order":"desc"})
py_data = response.json()
py_data
# Out:
# {'results_found': 598,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 4249,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '4249',
#     'name': "Wenger's",
#     'url': 'https://www.zomato.com/ncr/wengers-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'A 16, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6334507026',
#      'longitude': '77.2180680558',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Bakery, Fast Food, Desserts',
#     'timings': '11 AM to 8 PM',
#     'average_cost_for_two': 400,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Debit Card',
#      'No Seating Available',
#      'Credit Card',
#      'Takeaway Available',
#      'Cash',
#      'Air Conditioned',
#      'Desserts and Bakes'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/4249_CHAIN_e9b69e36e0296bd6cd7b92392c2af739.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.8'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 5270},
#     'all_reviews_count': 2517,
#     'photos_url': 'https://www.zomato.com/ncr/wengers-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 3371,
#     'menu_url': 'https://www.zomato.com/ncr/wengers-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/4249_CHAIN_e9b69e36e0296bd6cd7b92392c2af739.jpg?output-format=webp',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/4249',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/wengers-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '011 23324403, 011 23324594, 011 23328589',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Bakery'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 310143,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '310143',
#     'name': 'Natural Ice Cream',
#     'url': 'https://www.zomato.com/NaturalsCP?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'L-8, L Block, Outer Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6344491660',
#      'longitude': '77.2220343724',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Ice Cream',
#     'timings': '9 AM to 12 Midnight',
#     'average_cost_for_two': 200,
#     'price_range': 1,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Credit Card',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Desserts and Bakes',
#      'Digital Payments Accepted'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/313368/da7c191473cdc9701aa97a8cbcd51255.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.8'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 10197},
#     'all_reviews_count': 2493,
#     'photos_url': 'https://www.zomato.com/NaturalsCP/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 2438,
#     'menu_url': 'https://www.zomato.com/NaturalsCP/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/313368/da7c191473cdc9701aa97a8cbcd51255.jpg',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/310143',
#     'order_url': 'https://www.zomato.com/NaturalsCP/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/NaturalsCP/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '011 43785502, +91 8368436163',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Dessert Parlour'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18919107,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '18919107',
#     'name': 'The Big Chill Cafe',
#     'url': 'https://www.zomato.com/ncr/the-big-chill-cafe-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'First Floor, B 40, The Colonnade, Opposite Gate 2 Rajiv Chowk Metro Station, Connaught Place, New Delhi',
#      'locality': 'The Colonnade, Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6345239106',
#      'longitude': '77.2190363333',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'The Colonnade, Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Cafe',
#     'timings': '12 Noon to 11:30 PM',
#     'average_cost_for_two': 1500,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Lunch',
#      'Takeaway Available',
#      'Credit Card',
#      'Cash',
#      'Debit Card',
#      'Indoor Seating',
#      'Wifi',
#      'Table booking recommended',
#      'Air Conditioned',
#      'Desserts and Bakes',
#      'Reopened'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/reviews_photos/d21/624046414aaa5005c33b5dd05c525d21_1544194067.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.8',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.8'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 1199},
#     'all_reviews_count': 635,
#     'photos_url': 'https://www.zomato.com/ncr/the-big-chill-cafe-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1229,
#     'menu_url': 'https://www.zomato.com/ncr/the-big-chill-cafe-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/reviews_photos/d21/624046414aaa5005c33b5dd05c525d21_1544194067.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18919107',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/the-big-chill-cafe-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '011 41757075',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Café'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 301114,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '301114',
#     'name': "Wenger's Deli",
#     'url': 'https://www.zomato.com/ncr/wengers-deli-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'A 18, Radial Road, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6336902405',
#      'longitude': '77.2183409706',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Fast Food, Desserts, Beverages',
#     'timings': '11 AM to 7:45 PM (Mon-Fri), 11:30 AM to 8:45 PM (Sat-Sun)',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Takeaway Available',
#      'Debit Card',
#      'Dinner',
#      'Cash',
#      'Credit Card',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Desserts and Bakes'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/4249_CHAIN_e9b69e36e0296bd6cd7b92392c2af739.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.7'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 2289},
#     'all_reviews_count': 1388,
#     'photos_url': 'https://www.zomato.com/ncr/wengers-deli-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 2712,
#     'menu_url': 'https://www.zomato.com/ncr/wengers-deli-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/4249_CHAIN_e9b69e36e0296bd6cd7b92392c2af739.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/301114',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/wengers-deli-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '011 23328589',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 900,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '900',
#     'name': 'Saravana Bhavan',
#     'url': 'https://www.zomato.com/ncr/saravana-bhavan-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'P-13, Connaught Circus, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6322777239',
#      'longitude': '77.2165653482',
#      'zipcode': '0',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'South Indian, Mithai, Beverages',
#     'timings': '8 AM to 11 PM',
#     'average_cost_for_two': 500,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery',
#      'Debit Card',
#      'Dinner',
#      'Takeaway Available',
#      'Credit Card',
#      'Lunch',
#      'Cash',
#      'Breakfast',
#      'Ticket Restaurant',
#      'Pure Veg',
#      'Digital Payments Accepted',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Sodexo',
#      'Serves Jain Food',
#      'Reopened'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/899_CHAIN_8b679bb604a1a4f128971906e6027c05.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.6'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 8311},
#     'all_reviews_count': 4524,
#     'photos_url': 'https://www.zomato.com/ncr/saravana-bhavan-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 4811,
#     'menu_url': 'https://www.zomato.com/ncr/saravana-bhavan-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/899_CHAIN_8b679bb604a1a4f128971906e6027c05.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/900',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/saravana-bhavan-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '011 28844305, 011 23345577',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 301489,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '301489',
#     'name': 'Barbeque Nation',
#     'url': 'https://www.zomato.com/ncr/barbeque-nation-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '2nd Floor, Munshilal Building, Block N, Outer Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6303528452',
#      'longitude': '77.2207485884',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Beverages',
#     'timings': '12noon – 3:30pm, 6pm – 11pm (Mon-Sun)',
#     'average_cost_for_two': 1600,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Air Conditioned',
#      'Fullbar',
#      'Indoor Seating',
#      'Table booking recommended',
#      'Reopened',
#      'Wifi',
#      'Buffet',
#      'Outdoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/2/1212/b6429ddad24625e65344caabb921bd57.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.6',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.6'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 4903},
#     'all_reviews_count': 2279,
#     'photos_url': 'https://www.zomato.com/ncr/barbeque-nation-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 3300,
#     'menu_url': 'https://www.zomato.com/ncr/barbeque-nation-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/2/1212/b6429ddad24625e65344caabb921bd57.jpg',
#     'medio_provider': 1,
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/301489',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/ncr/barbeque-nation-connaught-place-new-delhi/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/ncr/barbeque-nation-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '080 61756005',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 18233593,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '18233593',
#     'name': 'Farzi Cafe',
#     'url': 'https://www.zomato.com/ncr/farzi-cafe-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '38/39, Level 1, Block E, Inner Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6324804801',
#      'longitude': '77.2211901471',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Modern Indian, Fast Food, Continental, Bar Food, North Indian',
#     'timings': '12noon – 1am (Mon-Sun)',
#     'average_cost_for_two': 2500,
#     'price_range': 4,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Credit Card',
#      'Cash',
#      'Debit Card',
#      'Delivery',
#      'Lunch',
#      'Takeaway Available',
#      'Smoking Area',
#      'Table booking recommended',
#      'Reopened',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Live Music',
#      'Wifi',
#      'Fullbar'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/18233593_RESTAURANT_00272acd0235af309a0bbe4843e53499.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.5'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 4232},
#     'all_reviews_count': 2911,
#     'photos_url': 'https://www.zomato.com/ncr/farzi-cafe-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 10760,
#     'menu_url': 'https://www.zomato.com/ncr/farzi-cafe-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/18233593_RESTAURANT_00272acd0235af309a0bbe4843e53499.jpg',
#     'medio_provider': 1,
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18233593',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/ncr/farzi-cafe-connaught-place-new-delhi/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/ncr/farzi-cafe-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9599889700, +91 9599889701',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 0, 'takeaway': -1},
#      'res_id': 311369,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '311369',
#     'name': "Tamra - Shangri-La's - Eros Hotel",
#     'url': 'https://www.zomato.com/ncr/tamra-shangri-las-eros-hotel-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': "Shangri-La's - Eros Hotel, 19, Level 1, Ashoka Road, Connaught Place, New Delhi",
#      'locality': "Shangri-La's - Eros Hotel, Connaught Place",
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6211052250',
#      'longitude': '77.2169569507',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': "Shangri-La's - Eros Hotel, Connaught Place, New Delhi"},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, Continental, Italian, Chinese, Thai, Desserts',
#     'timings': '12noon – 10pm (Mon-Sun)',
#     'average_cost_for_two': 3800,
#     'price_range': 4,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Delivery',
#      'Takeaway Available',
#      'Credit Card',
#      'Debit Card',
#      'Lunch',
#      'Buffet',
#      'Air Conditioned',
#      'Gourmet',
#      'Luxury Dining',
#      '4/5 Star',
#      'Fullbar',
#      'Kid Friendly',
#      'Indoor Seating',
#      'Brunch',
#      'Table booking recommended',
#      'Valet Parking Available',
#      'Smoking Area',
#      'Reopened'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/9/311369/26ce5b77d0291ea77d0942f5acb11354.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.5',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.5'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 964},
#     'all_reviews_count': 508,
#     'photos_url': 'https://www.zomato.com/ncr/tamra-shangri-las-eros-hotel-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 2130,
#     'menu_url': 'https://www.zomato.com/ncr/tamra-shangri-las-eros-hotel-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/9/311369/26ce5b77d0291ea77d0942f5acb11354.jpg',
#     'medio_provider': 1,
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/311369',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/tamra-shangri-las-eros-hotel-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '011 41191010, 011 41191011, +91 9599787836',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Fine Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18454488,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '18454488',
#     'name': 'The G.T. Road',
#     'url': 'https://www.zomato.com/ncr/the-g-t-road-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'M 39, Outer Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6331346529',
#      'longitude': '77.2229161486',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'North Indian, BBQ, Mughlai, Desserts, Beverages',
#     'timings': '12noon – 3:30pm, 7pm – 11:30pm (Mon-Sun)',
#     'average_cost_for_two': 1500,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Lunch',
#      'Credit Card',
#      'Debit Card',
#      'Dinner',
#      'Cash',
#      'Fullbar',
#      'Table reservation required',
#      'Reopened',
#      'Indoor Seating',
#      'Air Conditioned',
#      'Buffet',
#      'Desserts and Bakes'],
#     'offers': [],
#     'zomato_events': [{'event': {'event_id': 469254,
#        'friendly_start_date': '12 August',
#        'friendly_end_date': '31 December',
#        'friendly_timing_str': 'Wednesday, 12th August - Thursday, 31st December',
#        'start_date': '2020-08-12',
#        'end_date': '2020-12-31',
#        'end_time': '23:55:00',
#        'start_time': '12:00:00',
#        'is_active': 1,
#        'date_added': '2020-08-12 16:35:17',
#        'photos': [{'photo': {'url': 'https://b.zmtcdn.com/data/zomato_events/photos/9a2/35f01e8a87a074d808d8c621a6eb39a2_1597230415.jpeg',
#           'thumb_url': 'https://b.zmtcdn.com/data/zomato_events/photos/9a2/35f01e8a87a074d808d8c621a6eb39a2_1597230415.jpeg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#           'order': 0,
#           'md5sum': '35f01e8a87a074d808d8c621a6eb39a2',
#           'id': 634784,
#           'photo_id': 634784,
#           'uuid': 1597230390831527,
#           'type': 'NORMAL'}}],
#        'restaurants': [],
#        'is_valid': 1,
#        'share_url': 'http://www.zoma.to/r/0',
#        'show_share_url': 0,
#        'title': 'New Menu at Special Rates!',
#        'description': 'Now enjoy all new Menu at special rates!\nVisit The G.T. Road or call  9871121428!',
#        'display_time': '12:00 pm - 11:55 pm',
#        'display_date': '12 August - 31 December',
#        'is_end_time_set': 1,
#        'disclaimer': 'Restaurants are solely responsible for the service; availability and quality of the events including all or any cancellations/ modifications/ complaints.',
#        'event_category': 1,
#        'event_category_name': '',
#        'book_link': '',
#        'types': [{'name': 'SPECIAL MENU', 'color': '#F96C6A'}],
#        'share_data': {'should_show': 0}}}],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/8/18454488/18529e4f622485a316903afe8f37b426.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 3337},
#     'all_reviews_count': 1993,
#     'photos_url': 'https://www.zomato.com/ncr/the-g-t-road-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 7303,
#     'menu_url': 'https://www.zomato.com/ncr/the-g-t-road-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/8/18454488/18529e4f622485a316903afe8f37b426.jpg?output-format=webp',
#     'medio_provider': 1,
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18454488',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/the-g-t-road-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9871121428',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18418277,
#      'is_grocery_store': False},
#     'apikey': 'fe2800d53acb7eea4371a2f92dad232b',
#     'id': '18418277',
#     'name': 'Ministry Of Beer',
#     'url': 'https://www.zomato.com/ncr/ministry-of-beer-connaught-place-new-delhi?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'M 44, Outer Circle, Connaught Place, New Delhi',
#      'locality': 'Connaught Place',
#      'city': 'New Delhi',
#      'city_id': 1,
#      'latitude': '28.6333279907',
#      'longitude': '77.2226573154',
#      'zipcode': '110001',
#      'country_id': 1,
#      'locality_verbose': 'Connaught Place, New Delhi'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Continental, Italian, Asian, Momos',
#     'timings': '12 Noon to 1 AM (Mon-Sun)',
#     'average_cost_for_two': 1700,
#     'price_range': 3,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Cash',
#      'Debit Card',
#      'Lunch',
#      'Credit Card',
#      'Dance Floor',
#      'Nightlife',
#      'Outdoor Seating',
#      'Indoor Seating',
#      'Table booking recommended',
#      'Air Conditioned',
#      'Wifi',
#      'Live Sports Screening',
#      'Fullbar',
#      'Live Music',
#      'Above 18 Only',
#      'Digital Payments Accepted',
#      'Axis Bank - Dining Delights',
#      'Smoking Area'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/7/18418277/844c3a3fbaaf85ae19831c502800ddbd.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 3531},
#     'all_reviews_count': 2173,
#     'photos_url': 'https://www.zomato.com/ncr/ministry-of-beer-connaught-place-new-delhi/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 10318,
#     'menu_url': 'https://www.zomato.com/ncr/ministry-of-beer-connaught-place-new-delhi/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/7/18418277/844c3a3fbaaf85ae19831c502800ddbd.jpg',
#     'medio_provider': 1,
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18418277',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/ncr/ministry-of-beer-connaught-place-new-delhi/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8800012061, +91 8800119277, +91 8800012060',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Microbrewery'],
#     'establishment_types': []}}]}

# %% [markdown]
# # Zomato Cuisine 1.5

# %%
response = requests.get('https://developers.zomato.com/api/v2.1/categories',
                        headers = {'user-key':'##################################'},
                       )
py_data = response.json()
for i in py_data["categories"]:
    if i["categories"]["name"]=="Cafes":
        print(i["categories"]["id"])
# Out:
# 6

# %% [markdown]
# # Zomato Cuisine 1.6

# %%
response = requests.get('https://developers.zomato.com/api/v2.1/search',
                        headers = {'user-key':'##################################'},
                       params={"entity_id":"104",
                               "entity_type":"subzone", 
                               "count":5,
                               "category":"6",
                               "cuisines":"73",
                               "sort":"rating",
                               "order":"desc"}
                       ) 
py_data = response.json()
for i in py_data["restaurants"]:
    print(i["restaurant"]["name"],i["restaurant"]["user_rating"]["aggregate_rating"],i["restaurant"]["id"])
# Out:
# Xero Degrees 4.3 18729557
# The Art House Bar n Cafe 4.2 18863766
# Chaayos - Meri Wali Chai 4.1 18237315
# Cafe Delhi Heights 4.0 18579363
# Cafe Coffee Day - The Square 3.8 303034

# %% [markdown]
# # Zomato Cuisine 1.7

# %%
response = requests.get('https://developers.zomato.com/api/v2.1/reviews',
                        headers = {'user-key':'##################################'},
                       params={"res_id":"18729557", "count":5}
                       )
py_data = response.json()
for i in py_data["user_reviews"]:
    print(i["review"]["user"]["name"], i["review"]["rating"], i["review"]["review_text"])
# Out:
# Ananya Srivastava 5 Xero Degrees! Everyone loves it. The pasta and fries are to die for.  Particularly Cheesy peri peri fries and white sauce pasta.
# Tarun Vann 5 Wanted to go to this place for a long time, and tbh this place is definitely worth the hype, Such a cool concept of getting fries in the jar. It is a cozy small place with awesome food. Will visit again for sure.
# Apoorv AV 4 Very nice place. Ambiance is unique and comfortable. Staff is friendly and service is on time. Had quite a few types of fries and sliders. Pizza was okay. Refresher was too good.
# Ritika Guher 4 One of my favourite cafe in cannaught place, they serve amazing food at reasonable price. I just love their food presentations. My all time favourite is peri peri cheesy fries and pizza fries. In shakes i highly recommend their red velvet shake. I recommend all in coolers except spicy xero degrees.  Service: 5/5
# Harshita Khosla 3
